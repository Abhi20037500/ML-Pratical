# %%
import numpy as np

# %%
# Random Sampling

# %%
import random

# %%
np.random.random(1)
# Out:
# array([0.48883064])

# %%
np.random.random((3,3))
# Out:
# array([[0.12499808, 0.3058094 , 0.43224733],
#        [0.9624666 , 0.56262839, 0.36089855],
#        [0.35739909, 0.83057989, 0.517086  ]])

# %%
np.random.randint(1,4)
# Out:
# 2

# %%
np.random.randint(1,4,(4,4))
# Out:
# array([[2, 3, 1, 1],
#        [2, 3, 2, 3],
#        [1, 2, 3, 1],
#        [2, 1, 2, 3]])

# %%
np.random.randint(1,4,(2,4,4))
# Out:
# array([[[1, 1, 1, 3],
#         [2, 2, 3, 2],
#         [2, 1, 1, 2],
#         [2, 3, 2, 2]],
#
#        [[1, 1, 2, 1],
#         [2, 3, 1, 2],
#         [3, 1, 3, 1],
#         [1, 3, 1, 3]]])

# %%
np.random.seed(10)

# %%
2**32-1
# Out:
# 4294967295

# %%
np.random.rand(3)
# Out:
# array([0.77132064, 0.02075195, 0.63364823])

# %%
np.random.randn(3,3)
# Out:
# array([[-0.01002595,  1.67080819, -0.66437971],
#        [-0.60555494, -0.65099088,  0.51256776],
#        [ 0.26238882, -0.58273165,  1.36842193]])

# %%
x=[1,2,3,4]

# %%
np.random.choice(x)
# Out:
# 3

# %%
for i in range(20):
   print(np.random.choice(x))
# Out:
# 2
# 1
# 1
# 3
# 2
# 4
# 3
# 2
# 2
# 2
# 4
# 2
# 3
# 2
# 1
# 3
# 3
# 3
# 2
# 1

# %%
np.random.permutation(x)
# Out:
# array([3, 1, 4, 2])

# %%
#STRING Operations,Comparison and information

# %%
ch_name = "Indian AI Production"
str1 = "Learning Python Numpy"

# %%
np.char.add(ch_name,str1)
# Out:
# array('Indian AI ProductionLearning Python Numpy', dtype='<U41')

# %%
np.char.lower(ch_name)
# Out:
# array('indian ai production', dtype='<U20')

# %%
np.char.upper(str1)
# Out:
# array('LEARNING PYTHON NUMPY', dtype='<U21')

# %%
np.char.center(str1,60)
# Out:
# array('                   Learning Python Numpy                    ',
#       dtype='<U60')

# %%
np.char.center(str1,60,fillchar ="*")
# Out:
# array('*******************Learning Python Numpy********************',
#       dtype='<U60')

# %%
np.char.split(ch_name)
# Out:
# array(list(['Indian', 'AI', 'Production']), dtype=object)

# %%
np.char.splitlines("hello\nINDIAN")
# Out:
# array(list(['hello', 'INDIAN']), dtype=object)

# %%
str4 = "dmy"
str5 = "dmy"

# %%
np.char.join([":","/"],[str4,str5])
# Out:
# array(['d:m:y', 'd/m/y'], dtype='<U5')

# %%
np.char.replace(ch_name,"AI","Artificial Intelligence")
# Out:
# array('Indian Artificial Intelligence Production', dtype='<U41')
